# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
plt.style.use('seaborn-white')

# %% [markdown]
# # Ctrk(Sump)

# %%
ee_ctrk_sump = np.array([50.9, 91.9, 82.5, 80.9, 38.1, 83.8, 87.4, 69.3, 86.1, 90.3, 92.1, 81.7, 89.6, 61.1, 88.4, 90.9, 64.6, 95.6, 93, 94.1])
mm_ctrk_sump = np.array([90.1, 93, 96.8, 89.1, 90.5, 91.8, 86.3, 99.2, 88.2, 90.9, 95.6, 75.3, 85.2, 98.6, 86.8, 98, 108.3, 92.4, 92, 92.6])
qq_ctrk_sump = np.array([37.7, 39.2, 64.6, 45.3, 59.9, 21.9, 55.9, 38.1, 34.4, 51.2, 63.1, 59, 62.2, 43.3, 47.8, 67.9, 52.1, 92.6])
tt_ctrk_sump = np.array([74, 46.5, 30.8, 29.5, 33.1, 24.4, 36, 41.3, 49.7, 33.4, 14.1, 19.7, 26.8, 23.4, 23.8, 39, 24.1, 38.5, 35.3, 17.8])

# %%
fig, ax = plt.subplots(figsize =(10, 7))

ax.hist(mm_ctrk_sump, bins = 100, label = "ee")
ax.hist(ee_ctrk_sump, bins = 100, label = "mm")
ax.hist(qq_ctrk_sump, bins = 100, label = "qq")
ax.hist(tt_ctrk_sump, bins = 100, label = "tt")
ax.legend(prop={'size': 15})
ax.set_title("Ctrk(Sump)")

ax.set_xlabel('Ctrk(Sump)')
ax.set_ylabel('Event count')

# Show plot

plt.savefig('Ctrk(Sump).png')

plt.show()

# %% [markdown]
# # Hcal(SumE)

# %%
ee_hcal_sume = np.zeros(20)
mm_hcal_sume = np.array([7, 8.7, 0, 8.5, 7.2, 4.3, 3.3, 2.9, 3, 6.7, 6.1, 6.8, 4.4, 5.7, 7.9, 2, 8.5, 6.7, 22.6, 5.7])
qq_hcal_sume = np.array([14.1, 9.9, 13, 7.7, 13.8, 8.8, 24.3, 13.8, 6.2, 5.5, 17.2, 8.5, 20.4, 4.3, 5.7, 10.6, 4.4, 16.4])
tt_hcal_sume = np.array([10.2, 8.2, 6.3, 4.1, 10.6, 11.7, 5.7, 20, 20.3, 6.9, 6.3, 3.8, 3.4, 17.1, 3.6, 4.4, 7.3, 0, 2.3, 5])

# %%
fig, ax_2 = plt.subplots(figsize =(10, 7))

ax_2.hist(ee_hcal_sume, bins = 150, label="ee")
ax_2.hist(mm_hcal_sume, bins = 150, label="mm")
ax_2.hist(qq_hcal_sume, bins = 150, label="qq")
ax_2.hist(tt_hcal_sume, bins = 150, label="tt")

ax_2.legend(prop={'size': 15})
ax_2.set_title("Hcal(SumE)")

ax_2.set_ylim([0,2.5])

ax_2.set_xlabel('Hcal(SumE)')
ax_2.set_ylabel('Event count')

# Show plot

plt.savefig('Hcal(SumE).png')

plt.show()

# %% [markdown]
# # Ctrk(N)

# %%
ee_hcal_ctrk = np.array([2,2,3,2,2,2,2,2,2,2,2,3,2,2,3,2,2,2,2,2])
mm_hcal_ctrk = np.array([2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2])
qq_hcal_ctrk = np.array([15,17,46,36,41,9,16,30,22,36,23,23,26,30,40,19,14,29])
tt_hcal_ctrk = np.array([5,2,2,2,2,2,4,2,2,2,2,2,2,5,2,2,2,5,2,2])

# %%
fig, ax_3 = plt.subplots(figsize =(10, 7))

ax_3.hist(ee_hcal_ctrk, bins = 150, label="ee")
ax_3.hist(mm_hcal_ctrk, bins = 150, label="mm")
ax_3.hist(qq_hcal_ctrk, bins = 150, label="qq")
ax_3.hist(tt_hcal_ctrk, bins = 150, label="tt")

ax_3.legend(prop={'size': 15})
ax_3.set_title("Ctrk(N)")

ax_3.set_ylim([0,47])

ax_3.set_xlabel('Ctrk(N)')
ax_3.set_ylabel('Event count')

# Show plot

plt.savefig('Ctrk(N).png')

plt.show()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Ecal(SumE)

# %%
ee_ecal_sume = np.array([2,2,3,2,2,2,2,2,2,2,2,3,2,2,3,2,2,2,2,2,])
mm_ecal_sume = np.array([2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2])
qq_ecal_sume = np.array([15,17,46,36,41,9,16,30,22,36,23,23,26,30,40,19,14,29])
tt_ecal_sume = np.array([5,2,2,2,2,2,4,2,2,2,2,2,2,5,2,2,2,5,2,2])

# %%
fig, ax_4 = plt.subplots(figsize =(10, 7))

ax_4.hist(ee_ecal_sume, bins = 150, label="ee")
ax_4.hist(mm_ecal_sume, bins = 150, label="mm")
ax_4.hist(qq_ecal_sume, bins = 150, label="qq")
ax_4.hist(tt_ecal_sume, bins = 150, label="tt")

ax_4.legend(prop={'size': 15})
ax_4.set_title("Ecal(SumE)")

ax_4.set_ylim([0,2.5])

ax_4.set_xlabel('Ecal(SumE)')
ax_4.set_ylabel('Event count')

# Show plot

plt.savefig('Ecal(SumE).png')

plt.show()
